# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt 
import os

# %%
import requests

receive = requests.get('https://tse1.mm.bing.net/th?id=OIP.wpEag04ki3jWt_RbJCUhbQHaE8&pid=Api&P=0&w=244&h=163')
with open(r'/home/tasneem/face6.jpg','wb') as f:
    f.write(receive.content)

# %%
img_array = cv2.imread('/home/tasneem/face5.jpg')  # convert to array 
#gray_img= cv2.cvtColor(img_array, cv2.COLOR_BGR2GRAY) #in case want to read it in gray
plt.imshow(img_array)  # graph it
plt.show()  # display!

# %%
face_Cascade = cv2.CascadeClassifier('Cascades/haarcascade_frontalface_default.xml')


faces = face_cascade.detectMultiScale(gray, 1.3, 5)

for (x,y,w,h) in faces:
    cv2.rectangle(img_array,(x,y),(x+w,y+h), (230,0,100), 2)
    color_img = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)   
    
plt.imshow(color_img)  
plt.show()
